# %%
from autodistill_grounded_sam import GroundedSAM
from autodistill.detection import CaptionOntology
from autodistill_yolov8 import YOLOv8
from autodistill_roboflow_universe import RoboflowUniverseModel
from autodistill.utils import plot

# %%
# define an ontology to map class names to our GroundingDINO prompt
# the ontology dictionary has the format {caption: class}
# where caption is the prompt sent to the base model, and class is the label that will
# be saved for that caption in the generated annotations
model_configs = [
    ("carplates-bi5bk", 1)
]

base_model = RoboflowUniverseModel(
    ontology=CaptionOntology(
        {
            "licence": "licence",
        }
),
    api_key="JowxUFgbZ4P1EuEjdMi1",
    model_configs=model_configs,
)

# label all images in a folder called `context_images`
base_model.label(
  input_folder="./images",
  output_folder="./dataset"
)

target_model = YOLOv8("yolov8n.pt")
target_model.train("./dataset/data.yaml", epochs=200)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Labeling images: 0it [00:00, ?it/s]
# Labeled dataset created - ready for distillation.
# New https://pypi.org/project/ultralytics/8.2.18 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.81 🚀 Python-3.9.19 torch-2.3.0+cu121 CPU
# yolo/engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=./dataset/data.yaml, epochs=200, patience=50, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=cpu, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=0, resume=False, amp=True, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=runs/detect/train5
# Downloading https://ultralytics.com/assets/Arial.ttf to /home/hapek/.config/Ultralytics/Arial.ttf...
# 100%|██████████| 755k/755k [00:00<00:00, 7.77MB/s]
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.Conv                  [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.Conv                  [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.C2f                   [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.C2f                   [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.C2f                   [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.SPPF                  [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  1    148224  ultralytics.nn.modules.C2f                   [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  1     37248  ultralytics.nn.modules.C2f                   [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.Conv                  [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  1    123648  ultralytics.nn.modules.C2f                   [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.Conv                  [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  1    493056  ultralytics.nn.modules.C2f                   [384, 256, 1]
#  22        [15, 18, 21]  1    751507  ultralytics.nn.modules.Detect                [1, [64, 128, 256]]
# Model summary: 225 layers, 3011043 parameters, 3011027 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias
# train: Scanning /media/hapek/SSD/OneDrive - Politechnika Wroclawska/Magisterka/dataset/train/labels... 217 images, 0 backgrounds, 0 corrupt: 100%|██████████| 217/217 [00:00<00:00, 1637.38it/s]
# train: New cache created: /media/hapek/SSD/OneDrive - Politechnika Wroclawska/Magisterka/dataset/train/labels.cache
# val: Scanning /media/hapek/SSD/OneDrive - Politechnika Wroclawska/Magisterka/dataset/valid/labels... 52 images, 0 backgrounds, 0 corrupt: 100%|██████████| 52/52 [00:00<00:00, 1696.84it/s]
# val: New cache created: /media/hapek/SSD/OneDrive - Politechnika Wroclawska/Magisterka/dataset/valid/labels.cache
# Plotting labels to runs/detect/train5/labels.jpg...
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs/detect/train5
# Starting training for 200 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/200         0G      1.542      3.947      1.454         14        640: 100%|██████████| 14/14 [01:03<00:00,  4.56s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:05<00:00,  2.87s/it]
#                    all         52         54     0.0025      0.722      0.094     0.0519
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/200         0G      1.398      3.399      1.291         12        640: 100%|██████████| 14/14 [01:02<00:00,  4.45s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:05<00:00,  2.71s/it]
#                    all         52         54    0.00321      0.926      0.358      0.216
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/200         0G      1.476      2.263      1.268         11        640: 100%|██████████| 14/14 [01:03<00:00,  4.57s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:05<00:00,  2.80s/it]
#                    all         52         54    0.00327      0.944       0.69      0.405
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/200         0G       1.44      1.911      1.223         18        640: 100%|██████████| 14/14 [01:00<00:00,  4.34s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:05<00:00,  2.88s/it]
#                    all         52         54    0.00308      0.889      0.488      0.234
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/200         0G      1.424      1.776      1.222         14        640: 100%|██████████| 14/14 [01:01<00:00,  4.39s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:06<00:00,  3.14s/it]
#                    all         52         54          1      0.202      0.753      0.374
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/200         0G      1.505      1.663       1.27         13        640: 100%|██████████| 14/14 [01:04<00:00,  4.63s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:05<00:00,  2.67s/it]
#                    all         52         54      0.796     0.0741      0.411      0.209
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/200         0G      1.427      1.503      1.237          7        640: 100%|██████████| 14/14 [01:00<00:00,  4.31s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:05<00:00,  2.79s/it]
#                    all         52         54      0.906      0.574      0.757      0.416
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/200         0G      1.517      1.571      1.265         16        640: 100%|██████████| 14/14 [01:00<00:00,  4.32s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:04<00:00,  2.48s/it]
#                    all         52         54      0.711      0.639       0.64      0.293
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/200         0G      1.588      1.654      1.321         19        640: 100%|██████████| 14/14 [01:00<00:00,  4.35s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:05<00:00,  2.71s/it]
#                    all         52         54      0.864       0.47      0.718      0.356
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/200         0G      1.475      1.544      1.284         17        640: 100%|██████████| 14/14 [01:05<00:00,  4.66s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:05<00:00,  2.78s/it]
#                    all         52         54      0.839      0.678      0.711      0.364
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/200         0G      1.446      1.467      1.268         12        640: 100%|██████████| 14/14 [01:05<00:00,  4.66s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:05<00:00,  2.91s/it]
0.559
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     195/200         0G     0.5668     0.3904     0.8842         18        640: 100%|██████████| 14/14 [00:55<00:00,  3.97s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:04<00:00,  2.32s/it]
#                    all         52         54       0.92      0.889      0.919      0.551
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     196/200         0G     0.5759     0.3921     0.8954         17        640: 100%|██████████| 14/14 [00:55<00:00,  3.94s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:04<00:00,  2.33s/it]
#                    all         52         54      0.941      0.885      0.921      0.543
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     197/200         0G     0.5476     0.3897     0.8709         13        640: 100%|██████████| 14/14 [00:55<00:00,  3.97s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:05<00:00,  2.51s/it]
#                    all         52         54      0.938      0.907      0.923      0.542
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     198/200         0G     0.5234     0.3685     0.8737         19        640: 100%|██████████| 14/14 [00:55<00:00,  3.97s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:04<00:00,  2.29s/it]
#                    all         52         54      0.934      0.907      0.923      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     199/200         0G     0.5528     0.3634     0.8706         16        640: 100%|██████████| 14/14 [00:55<00:00,  3.97s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:04<00:00,  2.48s/it]
#                    all         52         54      0.934      0.907      0.922      0.544
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     200/200         0G     0.5951     0.3913     0.8989         13        640: 100%|██████████| 14/14 [00:55<00:00,  3.97s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:05<00:00,  2.55s/it]
#                    all         52         54      0.904      0.907       0.92      0.541
#
# 200 epochs completed in 3.516 hours.
# Optimizer stripped from runs/detect/train5/weights/last.pt, 6.2MB
# Optimizer stripped from runs/detect/train5/weights/best.pt, 6.2MB
#
# Validating runs/detect/train5/weights/best.pt...
# Ultralytics YOLOv8.0.81 🚀 Python-3.9.19 torch-2.3.0+cu121 CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:04<00:00,  2.01s/it]
#                    all         52         54      0.927      0.941      0.946      0.563
# Speed: 1.5ms preprocess, 66.3ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to runs/detect/train5
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 29
#      26 target_model.train("./dataset/data.yaml", epochs=200)
#      28 # run inference on the new model
# ---> 29 pred = target_model.predict("./dataset/valid/your-image.jpg", confidence=0.5)
#      30 print(pred)
#      32 # optional: upload your model to Roboflow for deployment
#
# File ~/anaconda3/envs/pytorch/lib/python3.9/site-packages/autodistill_yolov8/yolov8.py:40, in YOLOv8.predict(self, input, confidence)
#      39 def predict(self, input: str, confidence=0.5) -> sv.Detections:
# ---> 40     return self.yolo(input, conf=confidence)
#
# File ~/anaconda3/envs/pytorch/lib/python3.9/site-packages/ultralytics/yolo/engine/model.py:111, in YOLO.__call__(self, source, stream, **kwargs)
#     109 def __call__(self, source=None, stream=False, **kwargs):
#     110     """Calls the 'predict' function with given arguments to perform object detection."""
# --> 111     return self.predict(source, stream, **kwargs)
#
# File ~/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/anaconda3/envs/pytorch/lib/python3.9/site-packages/ultralytics/yolo/engine/model.py:252, in YOLO.predict(self, source, stream, **kwargs)
#     250 else:  # only update args if predictor is already setup
#     251     self.predictor.args = get_cfg(self.predictor.args, overrides)
# --> 252 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~/anaconda3/envs/pytorch/lib/python3.9/site-packages/ultralytics/yolo/engine/predictor.py:157, in BasePredictor.__call__(self, source, model, stream)
#     155     return self.stream_inference(source, model)
#     156 else:
# --> 157     return list(self.stream_inference(source, model))
#
# File ~/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/_contextlib.py:35, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      32 try:
#      33     # Issuing `None` to a generator fires it up
#      34     with ctx_factory():
# ---> 35         response = gen.send(None)
#      37     while True:
#      38         try:
#      39             # Forward the response to our caller and get its next request
#
# File ~/anaconda3/envs/pytorch/lib/python3.9/site-packages/ultralytics/yolo/engine/predictor.py:195, in BasePredictor.stream_inference(self, source, model)
#     193     self.setup_model(model)
#     194 # Setup source every time predict is called
# --> 195 self.setup_source(source if source is not None else self.args.source)
#     197 # Check if save_dir/ label file exists
#     198 if self.args.save or self.args.save_txt:
#
# File ~/anaconda3/envs/pytorch/lib/python3.9/site-packages/ultralytics/yolo/engine/predictor.py:172, in BasePredictor.setup_source(self, source)
#     170 else:  # predict, segment
#     171     transforms = None
# --> 172 self.dataset = load_inference_source(source=source,
#     173                                      transforms=transforms,
#     174                                      imgsz=self.imgsz,
#     175                                      vid_stride=self.args.vid_stride,
#     176                                      stride=self.model.stride,
#     177                                      auto=self.model.pt)
#     178 self.source_type = self.dataset.source_type
#     179 if not getattr(self, 'stream', True) and (self.dataset.mode == 'stream' or  # streams
#     180                                           len(self.dataset) > 1000 or  # images
#     181                                           any(getattr(self.dataset, 'video_flag', [False]))):  # videos
#
# File ~/anaconda3/envs/pytorch/lib/python3.9/site-packages/ultralytics/yolo/data/build.py:203, in load_inference_source(source, transforms, imgsz, vid_stride, stride, auto)
#     201     dataset = LoadPilAndNumpy(source, imgsz=imgsz, stride=stride, auto=auto, transforms=transforms)
#     202 else:
# --> 203     dataset = LoadImages(source,
#     204                          imgsz=imgsz,
#     205                          stride=stride,
#     206                          auto=auto,
#     207                          transforms=transforms,
#     208                          vid_stride=vid_stride)
#     210 # Attach source types to the dataset
#     211 setattr(dataset, 'source_type', source_type)
#
# File ~/anaconda3/envs/pytorch/lib/python3.9/site-packages/ultralytics/yolo/data/dataloaders/stream_loaders.py:194, in LoadImages.__init__(self, path, imgsz, stride, auto, transforms, vid_stride)
#     192         files.append(p)  # files
#     193     else:
# --> 194         raise FileNotFoundError(f'{p} does not exist')
#     196 images = [x for x in files if x.split('.')[-1].lower() in IMG_FORMATS]
#     197 videos = [x for x in files if x.split('.')[-1].lower() in VID_FORMATS]
#
# FileNotFoundError: /media/hapek/SSD/OneDrive - Politechnika Wroclawska/Magisterka/dataset/valid/your-image.jpg does not exist

# %%
# run inference on the new model
pred = target_model.predict("./dataset/valid/Cars10.jpg", confidence=0.5)
print(pred)
# Out:
# image 1/1 /media/hapek/SSD/OneDrive - Politechnika Wroclawska/Magisterka/dataset/valid/Cars10.jpg: 640x640 1 licence, 156.9ms
# Speed: 5.0ms preprocess, 156.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'licence'}
# orig_img: array([[[205, 182, 136],
#         [204, 182, 134],
#         [207, 181, 134],
#         ...,
#         [ 69, 129,  88],
#         [ 95, 159, 117],
#         [111, 176, 131]],
#
#        [[226, 202, 156],
#         [222, 198, 152],
#         [222, 196, 149],
#         ...,
#         [ 66, 128,  88],
#         [ 96, 159, 117],
#         [111, 175, 133]],
#
#        [[237, 211, 165],
#         [234, 208, 162],
#         [233, 205, 158],
#         ...,
#         [ 54, 116,  76],
#         [ 82, 145, 103],
#         [ 97, 161, 119]],
#
#        ...,
#
#        [[196, 208, 208],
#         [196, 208, 208],
#         [195, 207, 207],
#         ...,
#         [182, 192, 192],
#         [189, 199, 199],
#         [194, 204, 204]],
#
#        [[196, 208, 208],
#         [196, 208, 208],
#         [195, 207, 207],
#         ...,
#         [184, 194, 194],
#         [191, 201, 201],
#         [195, 205, 205]],
#
#        [[196, 208, 208],
#         [196, 208, 208],
#         [195, 207, 207],
#         ...,
#         [180, 190, 190],
#         [187, 197, 197],
#         [190, 200, 200]]], dtype=uint8)
# orig_shape: (864, 843)
# path: '/media/hapek/SSD/OneDrive - Politechnika Wroclawska/Magisterka/dataset/valid/Cars10.jpg'
# probs: None
# speed: {'preprocess': 5.022287368774414, 'inference': 156.91113471984863, 'postprocess': 0.7753372192382812}]

# %%
# !pip install ultralytics==8.0.196
# Out:
# Requirement already satisfied: ultralytics==8.0.196 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (8.0.196)
# Requirement already satisfied: matplotlib>=3.3.0 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from ultralytics==8.0.196) (3.9.0)
# Requirement already satisfied: numpy>=1.22.2 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from ultralytics==8.0.196) (1.26.4)
# Requirement already satisfied: opencv-python>=4.6.0 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from ultralytics==8.0.196) (4.9.0.80)
# Requirement already satisfied: pillow>=7.1.2 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from ultralytics==8.0.196) (10.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from ultralytics==8.0.196) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from ultralytics==8.0.196) (2.32.0)
# Requirement already satisfied: scipy>=1.4.1 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from ultralytics==8.0.196) (1.13.0)
# Requirement already satisfied: torch>=1.8.0 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from ultralytics==8.0.196) (2.3.0)
# Requirement already satisfied: torchvision>=0.9.0 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from ultralytics==8.0.196) (0.18.0)
# Requirement already satisfied: tqdm>=4.64.0 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from ultralytics==8.0.196) (4.66.4)
# Requirement already satisfied: pandas>=1.1.4 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from ultralytics==8.0.196) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from ultralytics==8.0.196) (0.13.2)
# Requirement already satisfied: psutil in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from ultralytics==8.0.196) (5.9.8)
# Requirement already satisfied: py-cpuinfo in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from ultralytics==8.0.196) (9.0.0)
# Requirement already satisfied: thop>=0.1.1 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from ultralytics==8.0.196) (0.1.1.post2209072238)
# Requirement already satisfied: contourpy>=1.0.1 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (6.4.0)
# Requirement already satisfied: pytz>=2020.1 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from pandas>=1.1.4->ultralytics==8.0.196) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from pandas>=1.1.4->ultralytics==8.0.196) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from requests>=2.23.0->ultralytics==8.0.196) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from requests>=2.23.0->ultralytics==8.0.196) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from requests>=2.23.0->ultralytics==8.0.196) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from requests>=2.23.0->ultralytics==8.0.196) (2023.7.22)
# Requirement already satisfied: filelock in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.0.196) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.0.196) (4.11.0)
# Requirement already satisfied: sympy in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.0.196) (1.12)
# Requirement already satisfied: networkx in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.0.196) (3.2.1)
# Requirement already satisfied: jinja2 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.0.196) (3.1.4)
# Requirement already satisfied: fsspec in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.0.196) (2024.5.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.0.196) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.0.196) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.0.196) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.0.196) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.0.196) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.0.196) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.0.196) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.0.196) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.0.196) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.0.196) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.0.196) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics==8.0.196) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->ultralytics==8.0.196) (12.4.127)
# Requirement already satisfied: six in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from cycler>=0.10->matplotlib>=3.3.0->ultralytics==8.0.196) (1.16.0)
# Requirement already satisfied: zipp>=3.1.0 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.3.0->ultralytics==8.0.196) (3.18.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from jinja2->torch>=1.8.0->ultralytics==8.0.196) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /home/hapek/anaconda3/envs/pytorch/lib/python3.9/site-packages (from sympy->torch>=1.8.0->ultralytics==8.0.196) (1.3.0)

# %%
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.0.81, to fix: `pip install ultralytics==8.0.196`
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# To exit: use 'exit', 'quit', or Ctrl-D.
